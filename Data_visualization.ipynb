# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
x = pd.read_csv("iris.csv")
print(x) 
print(x.shape)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]
# (150, 5)

# %%
print(x.columns)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
x["variety"].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
x.plot(kind='scatter', x = 'sepal.length',y = 'sepal.width') ;
plt.show()

# %%
plt.scatter(x['sepal.length'], x['sepal.width'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot of Sepal Length vs Width')
plt.show()

# %%
plt.scatter(x['petal.length'], x['petal.width'])
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Scatter Plot of Petal Length vs Width')
plt.show()

# %%
x.hist(column='sepal.length', bins=50)
plt.title('Histogram of sepal length')
plt.show()

# %%
x.hist(column='sepal.width', bins=50)
plt.title('Histogram of Sepal Width')
plt.show()

# %%
x.hist(column='petal.length', bins=50)
plt.title('Histogram of Petal Length')
plt.show()

# %%
x.hist(column='petal.width', bins=50)
plt.title('Histogram of Petal Width')
plt.show()
